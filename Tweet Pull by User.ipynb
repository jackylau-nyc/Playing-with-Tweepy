# %%
# settings.py
from dotenv import load_dotenv
load_dotenv()

# OR, the same with increased verbosity
load_dotenv(verbose=True)

# OR, explicitly providing path to '.env'
from pathlib import Path  # Python 3.6+ only
env_path = Path('.') / '.env'
load_dotenv(dotenv_path=env_path)
# Out:
# True

# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
import os
consumer_key = os.getenv("consumer_key")
consumer_secret = os.getenv("consumer_secret")
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
api = tweepy.API(auth)

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
user = api.get_user("realDonaldTrump")
user_timeline = user.timeline()
df3 = extract_timeline_as_df(user_timeline)
df3.head()
# Out:
#                            source_url  \
# 0          https://studio.twitter.com
# 1  http://twitter.com/download/iphone
# 2  http://twitter.com/download/iphone
# 3  http://twitter.com/download/iphone
# 4  http://twitter.com/download/iphone
#
#                                                 text                   id  \
# 0                            https://t.co/DFvnZjg2Eh  1309624557897240576
# 1  I will NEVER let you down! https://t.co/bqh7UA...  1309619971098632199
# 2  A three year HOAX. A failed COUP! https://t.co...  1309617799850004480
# 3  RT @BrookeSingman: NEW: FBI agent William J. B...  1309617433976672256
# 4  RT @joshgerstein: Just before midnight last ni...  1309617299335385088
#
#                 id_str  favorite_count  retweet_count  quoted_status_id lang  \
# 0  1309624557897240576           11602           4763               NaN  und
# 1  1309619971098632199           23356           7157               NaN   en
# 2  1309617799850004480           25969           8990      1.309455e+18   en
# 3  1309617433976672256               0           2434               NaN   en
# 4  1309617299335385088               0           2878               NaN   en
#
#                  source quoted_status_id_str             user           author
# 0  Twitter Media Studio                  NaN  realDonaldTrump  realDonaldTrump
# 1    Twitter for iPhone                  NaN  realDonaldTrump  realDonaldTrump
# 2    Twitter for iPhone  1309454867300339712  realDonaldTrump  realDonaldTrump
# 3    Twitter for iPhone                  NaN  realDonaldTrump  realDonaldTrump
# 4    Twitter for iPhone                  NaN  realDonaldTrump  realDonaldTrump
